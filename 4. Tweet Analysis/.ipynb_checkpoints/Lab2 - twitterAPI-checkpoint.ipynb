# %% [markdown]
# # IMT547 - SP19
# ## Topic: Collecting Twitter Data Demo
# ### Instructor: Li Zeng (lizeng@uw.edu) - April 17, 2019

# %% [markdown]
# ### Preparation

# %%
# Import the necessary package to process Json data
import json

# Import the twitter library to interact with the Twitter APIs
import twitter

# %%
# Your credentials - keep them safe!
# Alternatively, you can load your credential info from a seperate file (safer)
CONSUMER_KEY = 'CONSUMER KEY'
CONSUMER_SECRET = 'CONSUMER SECRET'
ACCESS_TOKEN = 'ACCESS TOKEN'
ACCESS_SECRET = 'ACCESS SECRET'

# %%
# Authenticate with Twitter in OAuth
oauth = twitter.OAuth(ACCESS_TOKEN, ACCESS_SECRET, CONSUMER_KEY, CONSUMER_SECRET)

# %% [markdown]
# ### Streaming API

# %%
# Initiate the connection to Twitter Streaming API
twitter_stream = twitter.TwitterStream(auth=oauth)

# Get a sample of the public data following through Twitter
#iterator = twitter_stream.statuses.sample()

# You can also specify filters
# more detail: https://developer.twitter.com/en/docs/tweets/filter-realtime/api-reference/post-statuses-filter.html
# and https://developer.twitter.com/en/docs/tweets/filter-realtime/guides/basic-stream-parameters
iterator = twitter_stream.statuses.filter(track= "Trump", language="en")

# %%
# Look at one single tweet
next(iterator)
# Out:
# {'created_at': 'Mon Apr 22 02:24:47 +0000 2019',
#  'id': 1120151433071013889,
#  'id_str': '1120151433071013889',
#  'text': 'RT @AshaRangappa_: Folks, the collusion is happening in plain sight, as we speak, in denying that the actions taken by the campaign were wr…',
#  'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>',
#  'truncated': False,
#  'in_reply_to_status_id': None,
#  'in_reply_to_status_id_str': None,
#  'in_reply_to_user_id': None,
#  'in_reply_to_user_id_str': None,
#  'in_reply_to_screen_name': None,
#  'user': {'id': 2712660258,
#   'id_str': '2712660258',
#   'name': 'Jean C',
#   'screen_name': 'ShawBatch',
#   'location': None,
#   'url': None,
#   'description': 'Truth. Justice. Cumberbatch. Marvel. And probably cats.',
#   'translator_type': 'none',
#   'protected': False,
#   'verified': False,
#   'followers_count': 297,
#   'friends_count': 550,
#   'listed_count': 19,
#   'favourites_count': 43037,
# ...

# %%
# Let's get a few more tweets!
# If you want more, you can get rid of the stop setting
# and let the Twitter API run for days longer
max_count = 10
current_count = 0
collection = []   
for tweet in iterator:
    # get tweet and append it to the collection
    collection.append(tweet)
    # count
    current_count += 1
    if current_count >= max_count:
        break

# %%
# now print our Twitter collection which contains 10 tweets
print("# of the tweets:", len(collection))
# then print out the raw tweets
print(collection)
# Out:
# # of the tweets: 10
# ...

# %% [markdown]
# Hard to read? Try to fit the data in a JSON format and use indent to make them more readable

# %%
# tweet collection in JSON format
print(json.dumps(collection, indent = 4))
# Out:
# [
#     {
#         "created_at": "Mon Apr 22 02:24:47 +0000 2019",
#         "id": 1120151433268072448,
#         "id_str": "1120151433268072448",
#         "text": "Trump asked spy chiefs to help counter Russia claims before Mueller probe began - MarketWatch https://t.co/lplzbwegBC",
#         "source": "<a href=\"http://twitter.com/download/iphone\" rel=\"nofollow\">Twitter for iPhone</a>",
#         "truncated": false,
#         "in_reply_to_status_id": null,
#         "in_reply_to_status_id_str": null,
#         "in_reply_to_user_id": null,
#         "in_reply_to_user_id_str": null,
#         "in_reply_to_screen_name": null,
#         "user": {
#             "id": 46295412,
#             "id_str": "46295412",
#             "name": "Citizenmdg",
#             "screen_name": "Clancy_Dew",
#             "location": null,
#             "url": null,
#             "description": null,
#             "translator_type": "none",
#             "protected": false,
# ...

# %% [markdown]
# You can store the collected tweets on your local machine

# %%
with open("tweet_example.json", "w") as write_file:
    json.dump(collection, write_file, indent = 4)
write_file.close()

# %% [markdown]
# ## Work with JSON file

# %%
data_list = [{"a":1, "b":2}, {"a":3,"b":4}, {"c":6,"d":2}]

# %%
# json dump
fout = open("output.json","w")
json.dump(data_list,fout)
# You can also dump the json file in a more readable format. Try it out!
#json.dump(data_list, fout, indent = 4)
fout.close()

# %%
# json load
fin = open("output.json","r")
data_list2 = json.load(fin)
fin.close()
data_list2
# Out:
# [{'a': 1, 'b': 2}, {'a': 3, 'b': 4}, {'c': 6, 'd': 2}]

# %%
# Print it using indent argument(Note the difference between json.dump() & json.dumps())
print(json.dumps(data_list2,indent=4))
# Out:
# [
#     {
#         "a": 1,
#         "b": 2
#     },
#     {
#         "a": 3,
#         "b": 4
#     },
#     {
#         "c": 6,
#         "d": 2
#     }
# ]

# %% [markdown]
# ### Exericse
#
# Reload the small sample of tweets you just stored in JSON file. Extract only the text field from each tweet and organize the these texts in a list, like:
# * ['Today is Tuesday', 'IMT547 is talking about data collection',..., 'I am learning to collect Twitter data']

# %%
#load json
file = open("tweet_example.json","r")
data_list = json.load(file)
file.close()
l=[]
for i in range(len(data_list)):
    l.append(data_list[i]['text'])   
print(l)
# Out:
# ['Trump asked spy chiefs to help counter Russia claims before Mueller probe began - MarketWatch https://t.co/lplzbwegBC', 'Are you serious?  You think I am dumb?  We got your number.', 'RT @RedNationRising: This is the America I know &amp; love! 🇺🇸 ❤️ \n\nAn African-American man stops to help an Asian-American woman with her car.…', '@realDonaldTrump Or a Trump supporters, Is This Your Idea On How To #MakeAmericaGreatAgain?', 'RT @TheDemocrats: Step into the DNC War Room--a research and rapid response unit entirely dedicated to taking on Trump’s corrupt administra…', "RT @krassenstein: Trump's Senior Adviser, Jared Kushner, is allowed to use his personal phone and Whatsapp to communicate with a known murd…", 'RT @DineshDSouza: Legally, a decision not to prosecute on the basis that no crimes were committed is an exoneration. Why? Because of the pr…', "yo @RoKhanna, \nwhat's the secret word you cultists say to Mr. Ineffective, @BernieSanders", 'RT @realDonaldTrump: The Trump Haters and
# ...

# %%
test = {'text': 1, 'name': 1}
test['text']
# Out:
# 1

# %% [markdown]
# ## Search Historical Tweets - Search API

# %%
# Initiate the connection to Twitter REST API
twitter = twitter.Twitter(auth=oauth)
            
# Search for latest tweets about "#marvel"
twitter.search.tweets(q='#marvel')
# Out:
# {'statuses': [{'created_at': 'Mon Apr 22 02:26:49 +0000 2019',
#    'id': 1120151944507432960,
#    'id_str': '1120151944507432960',
#    'text': 'Hoy 2x1 !! Maratón Marvel \n\n⭕Dr. Strange 🌟🌟\n⭕Thor: Ragnarok 😍\U0001f970♥️♥️♥️♥️\n\n#hbo #drstrange #thor #roadtoendgame… https://t.co/K1ZxG1SzGw',
#    'truncated': True,
#    'entities': {'hashtags': [{'text': 'hbo', 'indices': [72, 76]},
#      {'text': 'drstrange', 'indices': [77, 87]},
#      {'text': 'thor', 'indices': [88, 93]},
#      {'text': 'roadtoendgame', 'indices': [94, 108]}],
#     'symbols': [],
#     'user_mentions': [],
#     'urls': [{'url': 'https://t.co/K1ZxG1SzGw',
#       'expanded_url': 'https://twitter.com/i/web/status/1120151944507432960',
#       'display_url': 'twitter.com/i/web/status/1…',
#       'indices': [110, 133]}]},
#    'metadata': {'iso_language_code': 'es', 'result_type': 'recent'},
#    'source': '<a href="http://instagram.com" rel="nofollow">Instagram</a>',
#    'in_reply_to_status_id': None,
# ...

# %%
# Be aware of rate limit: 
# more detail: https://developer.twitter.com/en/docs/tweets/search/api-reference/get-search-tweets
twitter.search.tweets(q='#marvel', result_type='recent', lang='en', count=20)
# Out:
# {'statuses': [{'created_at': 'Mon Apr 22 02:26:44 +0000 2019',
#    'id': 1120151924983115776,
#    'id_str': '1120151924983115776',
#    'text': "Oi! THANOS! Get ready to FIGHT CUZ WE GOT THE GOD OF THUNDER AND VALKYRIE! 5 DAYS!\n-\n(I'm sorry I didn't add Bruce,… https://t.co/6iZPIgbwhv",
#    'truncated': True,
#    'entities': {'hashtags': [],
#     'symbols': [],
#     'user_mentions': [],
#     'urls': [{'url': 'https://t.co/6iZPIgbwhv',
#       'expanded_url': 'https://twitter.com/i/web/status/1120151924983115776',
#       'display_url': 'twitter.com/i/web/status/1…',
#       'indices': [117, 140]}]},
#    'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#    'source': '<a href="http://twitter.com" rel="nofollow">Twitter Web Client</a>',
#    'in_reply_to_status_id': 1119794104068653056,
#    'in_reply_to_status_id_str': '1119794104068653056',
#    'in_reply_to_user_id': 972712376742051840,
#    'in_reply_to_user_id_str': '972712376742051840',
# ...

# %% [markdown]
# ## Discover trends based on locations
#
# API doc: https://developer.twitter.com/en/docs/trends/locations-with-trending-topics/api-reference/get-trends-available

# %%
# Get all the locations where Twitter provides trends service
locations_info = twitter.trends.available(_woeid=1)

# %%
locations_info
# Out:
# [{'name': 'Worldwide',
#   'placeType': {'code': 19, 'name': 'Supername'},
#   'url': 'http://where.yahooapis.com/v1/place/1',
#   'parentid': 0,
#   'country': '',
#   'woeid': 1,
#   'countryCode': None},
#  {'name': 'Winnipeg',
#   'placeType': {'code': 7, 'name': 'Town'},
#   'url': 'http://where.yahooapis.com/v1/place/2972',
#   'parentid': 23424775,
#   'country': 'Canada',
#   'woeid': 2972,
#   'countryCode': 'CA'},
#  {'name': 'Ottawa',
#   'placeType': {'code': 7, 'name': 'Town'},
#   'url': 'http://where.yahooapis.com/v1/place/3369',
#   'parentid': 23424775,
#   'country': 'Canada',
#   'woeid': 3369,
#   'countryCode': 'CA'},
#  {'name': 'Quebec',
#   'placeType': {'code': 7, 'name': 'Town'},
#   'url': 'http://where.yahooapis.com/v1/place/3444',
#   'parentid': 23424775,
#   'country': 'Canada',
#   'woeid': 3444,
#   'countryCode': 'CA'},
#  {'name': 'Montreal',
#   'placeType': {'code': 7, 'name': 'Town'},
#   'url': 'http://where.yahooapis.com/v1/place/3534',
# ...

# %% [markdown]
# #### United States - Country Level
# {u'country': u'United States',
#   u'countryCode': u'US',
#   u'name': u'United States',
#   u'parentid': 1,
#   u'placeType': {u'code': 12, u'name': u'Country'},
#   u'url': u'http://where.yahooapis.com/v1/place/23424977',
#   u'woeid': 23424977}
#
# #### United States - Town Level
#  {u'country': u'United States',
#   u'countryCode': u'US',
#   u'name': u'Seattle',
#   u'parentid': 23424977,
#   u'placeType': {u'code': 7, u'name': u'Town'},
#   u'url': u'http://where.yahooapis.com/v1/place/2490383',
#   u'woeid': 2490383}
#
# A WOEID is a Yahoo! Where On Earth ID
#
# API doc: https://developer.twitter.com/en/docs/trends/locations-with-trending-topics/api-reference/get-trends-available

# %%
# Get trending topics in Seattle
seattle_trends = twitter.trends.place(_id = 2490383)

# %%
print(json.dumps(seattle_trends, indent=4))
# Out:
# [
#     {
#         "trends": [
#             {
#                 "name": "LAFC",
#                 "url": "http://twitter.com/search?q=LAFC",
#                 "promoted_content": null,
#                 "query": "LAFC",
#                 "tweet_volume": null
#             },
#             {
#                 "name": "#GameOfThornes",
#                 "url": "http://twitter.com/search?q=%23GameOfThornes",
#                 "promoted_content": null,
#                 "query": "%23GameOfThornes",
#                 "tweet_volume": 24383
#             },
#             {
#                 "name": "Sounders",
#                 "url": "http://twitter.com/search?q=Sounders",
#                 "promoted_content": null,
#                 "query": "Sounders",
#                 "tweet_volume": null
#             },
#             {
#                 "name": "Torres",
#                 "url": "http://twitter.com/search?q=Torres",
#                 "promoted_content": null,
# ...

# %% [markdown]
# ## Collect data about Twitter Users

# %% [markdown]
# #### Users Follower & Friends
# Potential for social network analysis on Twitter!
#
# API Doc:
# * Followers: https://developer.twitter.com/en/docs/accounts-and-users/follow-search-get-users/api-reference/get-followers-ids
# * Friends: https://developer.twitter.com/en/docs/accounts-and-users/follow-search-get-users/api-reference/get-friends-ids

# %%
# Retrieve some of Donald Trump's followers ids
twitter.followers.ids(screen_name="realDonaldTrump", count = 10)
# Out:
# {'ids': [1119860483970887680,
#   831206028712755200,
#   1120151490851590145,
#   1112042497537003520,
#   1119696936905396224,
#   2307071774,
#   1120151222210760708,
#   1120151551916400641,
#   1107364501505130497,
#   1120151196147130369],
#  'next_cursor': 1631479462067197045,
#  'next_cursor_str': '1631479462067197045',
#  'previous_cursor': 0,
#  'previous_cursor_str': '0',
#  'total_count': None}

# %%
# Retrieve some of Donald Trump's friends ids
twitter.friends.ids(screen_name="realDonaldTrump")
# Out:
# {'ids': [208155240,
#   818910970567344128,
#   2353605901,
#   17685258,
#   818927131883356161,
#   22703645,
#   56561449,
#   822215673812119553,
#   823367015830323201,
#   471672239,
#   20733972,
#   322293052,
#   720293443260456960,
#   2325495378,
#   245963716,
#   50769180,
#   22203756,
#   729676086632656900,
#   14669951,
#   475802156,
#   75541946,
#   41634520,
#   4121225056,
#   2908170952,
#   34852681,
#   25429371,
#   15513604,
#   108471631,
#   246500501,
#   14839147,
#   316865635,
#   26829777,
#   1222639789,
#   620571475,
#   633797941,
#   726414091,
#   82504071,
#   48223726,
#   1013672084,
#   29562422,
#   39349894,
#   23970102,
#   16031927,
#   216299334,
#   39344374,
#   52544275],
#  'next_cursor': 0,
#  'next_cursor_str': '0',
#  'previous_cursor': 0,
#  'previous_cursor_str': '0',
#  'total_count': None}

# %% [markdown]
# #### Users Timeline
# API Doc: https://developer.twitter.com/en/docs/tweets/timelines/api-reference/get-statuses-user_timeline

# %%
twitter.statuses.user_timeline(screen_name="realDonaldTrump", count = 3)
# Out:
# [{'created_at': 'Sun Apr 21 22:35:16 +0000 2019',
#   'id': 1120093671356022785,
#   'id_str': '1120093671356022785',
#   'text': 'How do you impeach a Republican President for a crime that was committed by the Democrats? MAKE AMERICA GREAT AGAIN!',
#   'truncated': False,
#   'entities': {'hashtags': [], 'symbols': [], 'user_mentions': [], 'urls': []},
#   'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>',
#   'in_reply_to_status_id': None,
#   'in_reply_to_status_id_str': None,
#   'in_reply_to_user_id': None,
#   'in_reply_to_user_id_str': None,
#   'in_reply_to_screen_name': None,
#   'user': {'id': 25073877,
#    'id_str': '25073877',
#    'name': 'Donald J. Trump',
#    'screen_name': 'realDonaldTrump',
#    'location': 'Washington, DC',
#    'description': '45th President of the United States of America🇺🇸',
#    'url': 'https://t.co/OMxB0x7xC5',
#    'entities': {'url': {'urls': [{'url': 'https://t.co/OMxB0x7xC5',
# ...

# %% [markdown]
# ### Check Rate Limit

# %%
twitter.application.rate_limit_status()
# Out:
# {'rate_limit_context': {'access_token': '1047874802474573824-3KFIrnFPNgo9oeth0AUle57xfZnSxs'},
#  'resources': {'lists': {'/lists/list': {'limit': 15,
#     'remaining': 15,
#     'reset': 1555900992},
#    '/lists/memberships': {'limit': 75, 'remaining': 75, 'reset': 1555900992},
#    '/lists/subscribers/show': {'limit': 15,
#     'remaining': 15,
#     'reset': 1555900992},
#    '/lists/members': {'limit': 900, 'remaining': 900, 'reset': 1555900992},
#    '/lists/subscriptions': {'limit': 15, 'remaining': 15, 'reset': 1555900992},
#    '/lists/show': {'limit': 75, 'remaining': 75, 'reset': 1555900992},
#    '/lists/ownerships': {'limit': 15, 'remaining': 15, 'reset': 1555900992},
#    '/lists/subscribers': {'limit': 180, 'remaining': 180, 'reset': 1555900992},
#    '/lists/members/show': {'limit': 15, 'remaining': 15, 'reset': 1555900992},
#    '/lists/statuses': {'limit': 900, 'remaining': 900, 'reset': 1555900992}},
# ...

# %% [markdown]
# ### Exercise
#
# Collect the recent 100 Twitter posts from a celebrity of interest. What is your strategy to figure out what these posts are talking about?
#
# Tips: for preliminary analysis, you can look at hashtags and word frequency. It is also great to create a visualization to aid your analysis (e.g. word cloud as I showed last week for the class background survey)

# %%
sp_tweets = twitter.statuses.user_timeline(screen_name="sundarpichai", count = 100)

# %%
# Print the text in these tweets
l=[] #list to store all the tweet texts
# print(len(sp_tweets))
for tweet in sp_tweets:
    l.append(tweet['text'])
print(l)
# Out:
# ['@SusanWojcicki @mipaltan @lionsdenkxip So jealous, you have no idea! That inning by @KieronPollard55 !! What a grea… https://t.co/glgpmRs664', 'Your Android phone can now be your security key for 2-step verification - it’s built into devices running Android 7… https://t.co/KpMVsthI1s', 'RT @Google: ✨Space-cial #GoogleDoodle Alert✨ https://t.co/eCwFjcGkJD', 'What an incredible effort by @ehtelescope scientists to capture the first black hole image - huge congrats! https://t.co/2zHuTz85wm', "In just over a year into our @Googleorg partnership with @GoodwillIntl, we've helped a quarter of a million America… https://t.co/oZpvZqzx6t", 'Today at #GoogleNext19, we unveiled our vision for a more helpful Cloud. Anthos brings together the simplicity of o… https://t.co/WdwMedXxt5', '#GrowWithGoogle coming to NYC: for the next five months, our new classroom space in Chelsea will be open for anyone… https://t.co/9CzMR5bX1X', 'Gmail turns 15 today, no joke:) Thank you to our 1.5B+ users around t
# ...

# %%
from PIL import Image
from wordcloud import WordCloud, STOPWORDS, ImageColorGenerator
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
#get the lines
text = " ".join(line for line in l)

#Remove the stop words
stopwords = set(STOPWORDS)
stopwords.update(["RT", "https", "www", "see", "will","com",'co'])

#generate the Word Cloud
wordcloud = WordCloud(stopwords=stopwords,max_font_size=50, max_words=150, background_color="white").generate(text)
plt.figure()
plt.imshow(wordcloud, interpolation="bilinear")
plt.axis("off")
plt.show()

# %%
#Hashatgs
# Print the text in these tweets
l=[] #list to store all the tweet texts
# print(len(sp_tweets))
for tweet in sp_tweets:
    if tweet['entities'] and tweet['entities']['hashtags']:
        l.append(tweet['entities']['hashtags'])
#print(l)
d={}
for word in l:
    #print(word[0]['text'])
    w = word[0]['text']
    if w in d:
        d[w] = d[w]+1
    else:
        d[w] = 1
sorted(d.items(),key = lambda kv:(kv[1], kv[0]))
# Out:
# [('BackToSchool', 1),
#  ('Berlin', 1),
#  ('Bolo', 1),
#  ('CSEdWeek', 1),
#  ('CampFire', 1),
#  ('DoodleForGoogle', 1),
#  ('ElectionDay', 1),
#  ('GDC2019', 1),
#  ('Gboard', 1),
#  ('GoVote', 1),
#  ('GoogleDoodle', 1),
#  ('GoogleNext19', 1),
#  ('GoogleServe', 1),
#  ('GrowWithGoogle', 1),
#  ('HBDAndroid', 1),
#  ('HBDGmail', 1),
#  ('HurricaneFlorence', 1),
#  ('HurricaneMichael', 1),
#  ('IWD2019', 1),
#  ('LWTSummit', 1),
#  ('MisterRogers', 1),
#  ('Pixel3', 1),
#  ('Pride', 1),
#  ('googledoodle', 1),
#  ('io19', 1),
#  ('madebygoogle', 1),
#  ('GoogleNext18', 2),
#  ('WorldCup', 2),
#  ('GoogleAI', 4)]

# %% [markdown]
# As we can see from the two analysis above (word cloud for the text in the tweets, GoogleAI seems to be the most frequnetly used term in these posts and that is what we conclude as most talked about thing in these tweets.
